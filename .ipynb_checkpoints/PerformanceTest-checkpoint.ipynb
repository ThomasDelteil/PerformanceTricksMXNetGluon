# %%
import multiprocessing
import time

import mxnet as mx
from mxnet import gluon, nd, autograd

import mxboard as mxb

from skimage.transform import resize

# %% [markdown]
# # Debugging MXNet Gluon
# ## And other performance tricks

# %% [markdown]
# ## 1) Visualizing Network

# %%
shape = (1, 3, 224, 224)

# %%
alexnet = gluon.model_zoo.vision.alexnet()
alexnet.initialize()

# %% [markdown]
# ### Gluon layers description

# %%
alexnet
# Out:
# AlexNet(
#   (features): HybridSequential(
#     (0): Conv2D(None -> 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): MaxPool2D(size=(3, 3), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     (2): Conv2D(None -> 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (3): MaxPool2D(size=(3, 3), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     (4): Conv2D(None -> 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Conv2D(None -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): Conv2D(None -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): MaxPool2D(size=(3, 3), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#     (8): Flatten
#     (9): Dense(None -> 4096, Activation(relu))
#     (10): Dropout(p = 0.5, axes=())
#     (11): Dense(None -> 4096, Activation(relu))
#     (12): Dropout(p = 0.5, axes=())
#   )
#   (output): Dense(None -> 1000, linear)
# )

# %%
mx.viz.plot_network(
    alexnet(mx.sym.var('data')), 
    shape={'data':shape},
    node_attrs={"shape":"oval","fixedsize":"false"}
)

# %%
mx.viz.print_summary(
    alexnet(mx.sym.var('data')), 
    shape={'data':shape}
)
# Out:
# ________________________________________________________________________________________________________________________
# Layer (type)                                        Output Shape            Param #     Previous Layer
# ========================================================================================================================
# data(null)                                          3x224x224               0
# ________________________________________________________________________________________________________________________
# alexnet0_conv0_fwd(Convolution)                     64x55x55                23296       data
# ________________________________________________________________________________________________________________________
# alexnet0_conv0_relu_fwd(Activation)                 64x55x55                0           alexnet0_conv0_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_pool0_fwd(Pooling)                         64x27x27                0           alexnet0_conv0_relu_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_conv1_fwd(Convolution)                     192x27x27               307392      alexnet0_pool0_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_conv1_relu_fwd(Activation)                 192x27x27               0           alexnet0_conv1_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_pool1_fwd(Pooling)                         192x13x13               0           alexnet0_conv1_relu_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_conv2_fwd(Convolution)                     384x13x13               663936      alexnet0_pool1_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_conv2_relu_fwd(Activation)                 384x13x13               0           alexnet0_conv2_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_conv3_fwd(Convolution)                     256x13x13               884992      alexnet0_conv2_relu_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_conv3_relu_fwd(Activation)                 256x13x13               0           alexnet0_conv3_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_conv4_fwd(Convolution)                     256x13x13               590080      alexnet0_conv3_relu_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_conv4_relu_fwd(Activation)                 256x13x13               0           alexnet0_conv4_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_pool2_fwd(Pooling)                         256x6x6                 0           alexnet0_conv4_relu_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_flatten0_reshape0(Reshape)                 9216                    0           alexnet0_pool2_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_dense0_fwd(FullyConnected)                 4096                    37752832    alexnet0_flatten0_reshape0
# ________________________________________________________________________________________________________________________
# alexnet0_dense0_relu_fwd(Activation)                4096                    0           alexnet0_dense0_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_dropout0_fwd(Dropout)                      4096                    0           alexnet0_dense0_relu_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_dense1_fwd(FullyConnected)                 4096                    16781312    alexnet0_dropout0_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_dense1_relu_fwd(Activation)                4096                    0           alexnet0_dense1_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_dropout1_fwd(Dropout)                      4096                    0           alexnet0_dense1_relu_fwd
# ________________________________________________________________________________________________________________________
# alexnet0_dense2_fwd(FullyConnected)                 1000                    4097000     alexnet0_dropout1_fwd
# ========================================================================================================================
# Total params: 61100840
# ________________________________________________________________________________________________________________________

# %%
#!rm -rf logs && mkdir logs

# %%
sw = mxb.SummaryWriter(logdir='logs', flush_secs=3)

# %%
alexnet.hybridize()
out = alexnet(mx.nd.ones(shape))

# %%
sw.add_graph(alexnet)

# %% [markdown]
# ## 2) Performance tricks

# %% [markdown]
# ## Model
#
# We get a relatively simple and common model architecture from the model the zoo, ResNet50 architecture

# %%
ctx = mx.gpu()
net = gluon.model_zoo.vision.resnet18_v2(pretrained=False, ctx=ctx)
net.initialize(mx.init.Xavier(magnitude=2.3), ctx=ctx)

# %% [markdown]
# ## Data

# %%
BATCH_SIZE = 64

# %%
def transform(x, y):
    x = resize(x.asnumpy(), (224, 224), anti_aliasing=False, mode='constant')
    x = x.transpose((2, 0, 1)).astype('float32')
    return x, y
dataset_train = gluon.data.vision.CIFAR10(train=True, transform=transform)

# %%
dataloader_train = gluon.data.DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=False, last_batch="discard")

# %% [markdown]
# ## Loss

# %%
loss_fn = gluon.loss.SoftmaxCELoss()

# %% [markdown]
# ## Metric

# %%
accuracy = mx.metric.Accuracy()

# %% [markdown]
# ## Optimizer

# %%
trainer = mx.gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate':0.001, 'momentum':0.9, 'wd':0.00001})

# %% [markdown]
# ## Training Loop

# %% [markdown]
# # Performance optimization

# %% [markdown]
# ### 1) Naive Attempt

# %%
# %%time

epoch = 1
print_n = 5
tick_0 = time.time()

for e in range(epoch):
    tick = time.time()
    for i, (data, label) in enumerate(dataloader_train):
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        
        # Forward pass and loss computation
        with autograd.record():
            output = net(data)
            loss = loss_fn(output, label)
        
        # Compute gradient
        loss.backward()
        
        # Update network weights
        trainer.step(data.shape[0])
        
        # Update metric
        accuracy.update(label, output)
        
        # Print batch metrics
        if i % print_n == 0 and i > 0:
            sw.add_scalar(tag='Accuracy', value={'naive':accuracy.get()[1]}, global_step=i-print_n)
            sw.add_scalar(tag='Speed', value={'naive':data.shape[0]*(print_n)/(time.time()-tick)}, global_step=i-print_n)
            print('Batch [{}], Accuracy {:.4f}, Samples/sec: {:.4f}'.format(
                i, accuracy.get()[1], data.shape[0]*(print_n)/(time.time()-tick))
            )
            tick = time.time()
        
        if i == 150:
            break
            
    print('Epoch [{}], Accuracy {:.4f}'.format(e, accuracy.get()[1]))
    print('~Samples/Sec {:.4f}'.format(data.shape[0]*(i+1)/(time.time()-tick_0)))
    accuracy.reset()
# Out:
# Batch [5], Accuracy 0.0000, Samples/sec: 116.3584
# Batch [10], Accuracy 0.0028, Samples/sec: 165.1788
# Batch [15], Accuracy 0.0234, Samples/sec: 164.2796
# Batch [20], Accuracy 0.0603, Samples/sec: 162.4644
# Batch [25], Accuracy 0.0901, Samples/sec: 164.3155
# Batch [30], Accuracy 0.1018, Samples/sec: 165.0399
# Batch [35], Accuracy 0.1181, Samples/sec: 164.2677
# Batch [40], Accuracy 0.1303, Samples/sec: 165.2929
# Batch [45], Accuracy 0.1437, Samples/sec: 164.3515
# Batch [50], Accuracy 0.1547, Samples/sec: 165.1600
# Batch [55], Accuracy 0.1618, Samples/sec: 164.4317
# Batch [60], Accuracy 0.1701, Samples/sec: 165.2705
# Batch [65], Accuracy 0.1773, Samples/sec: 164.3659
# Batch [70], Accuracy 0.1816, Samples/sec: 165.2258
# Batch [75], Accuracy 0.1904, Samples/sec: 164.3470
# Batch [80], Accuracy 0.1960, Samples/sec: 165.3469
# Batch [85], Accuracy 0.2035, Samples/sec: 164.4635
# Batch [90], Accuracy 0.2076, Samples/sec: 165.2014
# Batch [95], Accuracy 0.2127, Samples/sec: 164.2233
# Batch [100], Accuracy 0.2212, Samples/sec: 164.9650
# Batch [105], Accuracy 0.2245, Samples/sec: 163.8615
# Batch [110], Accuracy 0.2283, Samples/sec: 165.1031
# Batch [115], Accuracy 0.2355, Samples/sec: 164.0455
# Batch [120], Accuracy 0.2385, Samples/sec: 165.0793
# Batch [125], Accuracy 0.2417, Samples/sec: 164.2741
# Batch [130], Accuracy 0.2452, Samples/sec: 165.0250
# Batch [135], Accuracy 0.2490, Samples/sec: 164.3382
# Batch [140], Accuracy 0.2501, Samples/sec: 165.0928
# Batch [145], Accuracy 0.2530, Samples/sec: 164.3253
# Batch [150], Accuracy 0.2556, Samples/sec: 164.9205
# Epoch [0], Accuracy 0.2556
# ~Samples/Sec 163.4262
# CPU times: user 1min 30s, sys: 1min 36s, total: 3min 7s
# Wall time: 59.1 s

# %% [markdown]
# Notice how we are I/O constrained, very low GPU util, drops in GPU util and high CPU utilization

# %% [markdown]
# | Type    | CPU (%) | GPU Util (%) | GPU Memory (GB) | GPU Memory I/O (%) | Samples / sec  |
# |---------|---------|--------------|-----------------|--------------------|----------------|
# | 1) Naive| 10%     |    [0-80]%  |     70%          |     [0-53]%        |  141           |

# %% [markdown]
# ### 2) Using multiprocessing workers

# %%
dataloader_train = gluon.data.DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=False, last_batch="discard", 
                                         num_workers=multiprocessing.cpu_count()-3)
net.initialize(mx.init.Xavier(magnitude=2.3), ctx=ctx, force_reinit=True)

# %%
# %%time

epoch = 1
print_n = 5
tick_0 = time.time()

for e in range(epoch):
    tick = time.time()
    for i, (data, label) in enumerate(dataloader_train):
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        
        # Forward pass and loss computation
        with autograd.record():
            output = net(data)
            loss = loss_fn(output, label)
        
        # Compute gradient
        loss.backward()
        
        # Update network weights
        trainer.step(data.shape[0])
        
        # Update metric
        accuracy.update(label, output)
        
        # Print batch metrics
        if i % print_n == 0 and i > 0:
            sw.add_scalar(tag='Accuracy', value={'multi':accuracy.get()[1]}, global_step=i-print_n)
            sw.add_scalar(tag='Speed', value={'multi':data.shape[0]*(print_n)/(time.time()-tick)}, global_step=i-print_n)
            print('Batch [{}], Accuracy {:.4f}, Samples/sec: {:.4f}'.format(
                i, accuracy.get()[1], data.shape[0]*(print_n)/(time.time()-tick))
            )
            tick = time.time()
        
        if i == 150:
            break
            
    print('Epoch [{}], Accuracy {:.4f}'.format(e, accuracy.get()[1]))
    print('~Samples/Sec {:.4f}'.format(data.shape[0]*(i+1)/(time.time()-tick_0)))
    accuracy.reset()
# Out:
# Batch [5], Accuracy 0.0000, Samples/sec: 91.1842
# Batch [10], Accuracy 0.0241, Samples/sec: 535.9305
# Batch [15], Accuracy 0.0537, Samples/sec: 594.2227
# Batch [20], Accuracy 0.0789, Samples/sec: 564.7558
# Batch [25], Accuracy 0.0986, Samples/sec: 597.0601
# Batch [30], Accuracy 0.1154, Samples/sec: 636.5323
# Batch [35], Accuracy 0.1302, Samples/sec: 630.9169
# Batch [40], Accuracy 0.1410, Samples/sec: 669.6035
# Batch [45], Accuracy 0.1549, Samples/sec: 675.4419
# Batch [50], Accuracy 0.1624, Samples/sec: 567.7946
# Batch [55], Accuracy 0.1694, Samples/sec: 551.2461
# Batch [60], Accuracy 0.1770, Samples/sec: 670.0939
# Batch [65], Accuracy 0.1837, Samples/sec: 596.2188
# Batch [70], Accuracy 0.1873, Samples/sec: 693.4321
# Batch [75], Accuracy 0.1926, Samples/sec: 715.9974
# Batch [80], Accuracy 0.1977, Samples/sec: 617.7855
# Batch [85], Accuracy 0.2060, Samples/sec: 654.2617
# Batch [90], Accuracy 0.2117, Samples/sec: 659.3791
# Batch [95], Accuracy 0.2158, Samples/sec: 624.9859
# Batch [100], Accuracy 0.2214, Samples/sec: 550.6052
# Batch [105], Accuracy 0.2230, Samples/sec: 677.3641
# Batch [110], Accuracy 0.2272, Samples/sec: 624.4843
# Batch [115], Accuracy 0.2337, Samples/sec: 561.2841
# Batch [120], Accuracy 0.2361, Samples/sec: 741.5459
# Batch [125], Accuracy 0.2380, Samples/sec: 634.1434
# Batch [130], Accuracy 0.2413, Samples/sec: 676.0897
# Batch [135], Accuracy 0.2439, Samples/sec: 748.8508
# Batch [140], Accuracy 0.2458, Samples/sec: 514.0179
# Batch [145], Accuracy 0.2496, Samples/sec: 480.6614
# Batch [150], Accuracy 0.2523, Samples/sec: 530.2550
# Epoch [0], Accuracy 0.2523
# ~Samples/Sec 515.1668
# CPU times: user 11.6 s, sys: 5.06 s, total: 16.7 s
# Wall time: 18.8 s

# %% [markdown]
# We notice now that CPU utilization seems to be less than 100% so data fetching and resizing is no more the bottleneck

# %% [markdown]
# | Type              | CPU (%) | GPU Util (%)         | GPU Memory (GB) | GPU Memory I/O (%) | Samples / sec         |
# |---------          |---------|--------------        |-----------------|--------------------|----------------       |
# | 1) Naive          | 10%     |    [0-80]%           |     70%         |     [0-53]%        |  141                  |
# | 2) Multiprocessing| [30-45]%|    [74-93]%          |     90%         |     [50-60]%       |  302                  |

# %% [markdown]
# ### 3) Hybridization

# %%
net.initialize(mx.init.Xavier(magnitude=2.3), ctx=ctx, force_reinit=True)
net.hybridize(static_alloc=True, static_shape=True)
out = net(mx.nd.ones(shape, ctx))

# %%
# %%time

epoch = 1
print_n = 5
tick_0 = time.time()

for e in range(epoch):
    tick = time.time()
    for i, (data, label) in enumerate(dataloader_train):
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        
        # Forward pass and loss computation
        with autograd.record():
            output = net(data)
            loss = loss_fn(output, label)
        
        # Compute gradient
        loss.backward()
        
        # Update network weights
        trainer.step(data.shape[0])
        
        # Update metric
        accuracy.update(label, output)
        
        # Print batch metrics
        if i % print_n == 0 and i > 0:
            sw.add_scalar(tag='Accuracy', value={'hybrid':accuracy.get()[1]}, global_step=i-print_n)
            sw.add_scalar(tag='Speed', value={'hybrid':data.shape[0]*(print_n)/(time.time()-tick)}, global_step=i-print_n)
            print('Batch [{}], Accuracy {:.4f}, Samples/sec: {:.4f}'.format(
                i, accuracy.get()[1], data.shape[0]*(print_n)/(time.time()-tick))
            )
            tick = time.time()
        
        if i == 150:
            break
            
    print('Epoch [{}], Accuracy {:.4f}'.format(e, accuracy.get()[1]))
    print('~Samples/Sec {:.4f}'.format(data.shape[0]*(i+1)/(time.time()-tick_0)))
    accuracy.reset()
# Out:
# Batch [5], Accuracy 0.0000, Samples/sec: 86.5744
# Batch [10], Accuracy 0.0014, Samples/sec: 769.2795
# Batch [15], Accuracy 0.0176, Samples/sec: 584.9088
# Batch [20], Accuracy 0.0506, Samples/sec: 514.9183
# Batch [25], Accuracy 0.0811, Samples/sec: 555.4627
# Batch [30], Accuracy 0.0897, Samples/sec: 598.0154
# Batch [35], Accuracy 0.1055, Samples/sec: 654.2894
# Batch [40], Accuracy 0.1189, Samples/sec: 785.1194
# Batch [45], Accuracy 0.1345, Samples/sec: 637.2089
# Batch [50], Accuracy 0.1471, Samples/sec: 678.7013
# Batch [55], Accuracy 0.1557, Samples/sec: 587.0470
# Batch [60], Accuracy 0.1642, Samples/sec: 620.4511
# Batch [65], Accuracy 0.1728, Samples/sec: 772.0420
# Batch [70], Accuracy 0.1780, Samples/sec: 684.5479
# Batch [75], Accuracy 0.1887, Samples/sec: 869.1400
# Batch [80], Accuracy 0.1943, Samples/sec: 666.9035
# Batch [85], Accuracy 0.2008, Samples/sec: 575.7882
# Batch [90], Accuracy 0.2059, Samples/sec: 721.5596
# Batch [95], Accuracy 0.2114, Samples/sec: 691.1368
# Batch [100], Accuracy 0.2188, Samples/sec: 647.1839
# Batch [105], Accuracy 0.2218, Samples/sec: 618.8557
# Batch [110], Accuracy 0.2262, Samples/sec: 549.0322
# Batch [115], Accuracy 0.2317, Samples/sec: 668.8057
# Batch [120], Accuracy 0.2341, Samples/sec: 628.6866
# Batch [125], Accuracy 0.2367, Samples/sec: 593.5990
# Batch [130], Accuracy 0.2400, Samples/sec: 638.5965
# Batch [135], Accuracy 0.2443, Samples/sec: 651.9281
# Batch [140], Accuracy 0.2459, Samples/sec: 674.8832
# Batch [145], Accuracy 0.2499, Samples/sec: 618.0631
# Batch [150], Accuracy 0.2531, Samples/sec: 559.2594
# Epoch [0], Accuracy 0.2531
# ~Samples/Sec 526.2509
# CPU times: user 8.34 s, sys: 5.16 s, total: 13.5 s
# Wall time: 18.4 s

# %% [markdown]
# | Type              | CPU (%) | GPU Util (%)         | GPU Memory (GB) | GPU Memory I/O (%) | Samples / sec         |
# |---------          |---------|--------------        |-----------------|--------------------|----------------       |
# | 1) Naive          | 10%     |    [0-80]%           |     70%         |     [0-53]%        |  141                  |
# | 2) Multiprocessing| [30-45]%|    [74-93]%          |     90%         |     [50-60]%       |  302                  |
# | 3) Hybridization  | [30-45]%|    [83-94]%          |     90%         |     [50-60]%       |  320                  |

# %% [markdown]
# ### 4) Synchronization calls

# %%
net.initialize(mx.init.Xavier(magnitude=2.3), ctx=ctx, force_reinit=True)
accuracy.reset()

# %%
# %%time

epoch = 1
print_n_sync = 3
print_n = 6
tick_0 = time.time()

for e in range(epoch):
    tick = time.time()
    for i, (data, label) in enumerate(dataloader_train):
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)

        # Print batch metrics            
        if i % print_n == 0 and i > 0:
            sw.add_scalar(tag='Accuracy', value={'hybrid_sync':accuracy.get()[1]}, global_step=i-print_n)
            sw.add_scalar(tag='Speed', value={'hybrid_sync':data.shape[0]*(print_n)/(time.time()-tick)}, global_step=i-print_n)

            print('Batch [{}], Accuracy {:.4f}, Samples/sec: {:.4f}'.format(
                i, accuracy.get()[1], data.shape[0]*(print_n)/(time.time()-tick))
            )
            tick = time.time()
            
        # Forward pass and loss computation
        with autograd.record():
            output = net(data)
            loss = loss_fn(output, label)
            
        # Compute gradient
        loss.backward()
        
        # Update network weights
        trainer.step(data.shape[0])
        
        # Update metric
#        if i % print_n_sync == 0:
#            print('here', output.asnumpy(), label.asnumpy())
        accuracy.update(label, output)
#            print(accuracy.get())

        
        if i == 10:
            break
    print('Epoch [{}], Accuracy {:.4f}'.format(e, accuracy.get()[1]))
    print('~Samples/Sec {:.4f}'.format(data.shape[0]*(i+1)/(time.time()-tick_0)))
    accuracy.reset()
# Out:
# here [[ 0.34753054 -0.03346068  0.16986217 ... -0.10092039  0.3185774
#    0.03921079]
#  [ 0.5292186  -0.13020298  0.46892315 ... -0.16031557  0.28569514
#    0.21217044]
#  [ 0.7791431  -0.2781495   0.5432427  ... -0.1913579   0.45098528
#    0.04804237]
#  ...
#  [ 0.34988737  0.10672081  0.28143662 ... -0.04514033  0.35883588
#    0.0683898 ]
#  [ 0.45365798 -0.1545435   0.3078739  ... -0.12636621  0.2315111
#    0.11832228]
#  [ 0.39300182 -0.03752157  0.25374758 ...  0.00942973  0.40997764
#    0.17551781]] [6 9 9 4 1 1 2 7 8 3 4 7 7 2 9 9 9 3 2 6 4 3 6 6 2 6 3 5 4 0 0 9 1 3 4 0 3
#  7 3 3 5 2 2 7 1 1 1 2 2 0 9 5 7 9 2 2 5 2 4 3 1 1 8 2]
# ('accuracy', 0.0)
# here [[ 0.6004203  -0.10726344  0.43710044 ... -0.08775373  0.32261512
#    0.1744337 ]
#  [ 0.39301795  0.21460801  0.3026949  ... -0.08732598  0.28303078
#    0.06649403]
#  [ 0.41015977  0.17896126  0.32163662 ...  0.03142439  0.302219
#    0.01572666]
#  ...
#  [ 0.23538932  0.15508066  0.07445174 ... -0.08604011  0.32075703
#    0.10454497]
#  [ 0.1606434   0.24726504  0.00847436 ... -0.16151111  0.31250265
#    0.0187854 ]
#  [ 0.46166795 -0.39983577  0.47512975 ... -0.3611878   0.4232685
#    0.0481144 ]] [8 8 2 5 2 3 5 0 6 1 9 3 6 9 1 3 9 6 6 7 1 0 9 5 8 5 2 9 0 8 8 0 6 9 1 1 6
# %% [markdown]
# | Type              | CPU (%) | GPU Util (%)         | GPU Memory (GB) | GPU Memory I/O (%) | Samples / sec         |
# |---------          |---------|--------------        |-----------------|--------------------|----------------       |
# | 1) Naive          | 10%     |    [0-80]%           |     70%         |     [0-53]%        |  141                  |
# | 2) Multiprocessing| [30-45]%|    [74-93]%          |     90%         |     [50-60]%       |  302                  |
# | 3) Hybridization  | [30-45]%|    [83-94]%          |     90%         |     [50-60]%       |  320                  |
# | 4) Synchronization| [30-45]%|    [90-96]%          |     92%         |     [50-60]%       |  322                  |

# %% [markdown]
# ## 5) Tweaking hyper-parameters

# %%
BATCH_SIZE = 96
dataloader_train = gluon.data.DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=False, last_batch="discard", num_workers=multiprocessing.cpu_count()-3)

# %%
net.initialize(mx.init.Xavier(magnitude=2.3), ctx=ctx, force_reinit=True)
trainer = mx.gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate':0.001*1.5, 'momentum':0.9, 'wd':0.00001})

# %%
# %%time

epoch = 1
print_n_sync = 3
print_n = 6
tick_0 = time.time()

for e in range(epoch):
    tick = time.time()
    for i, (data, label) in enumerate(dataloader_train):
        data = data.as_in_context(ctx)
        label = label.as_in_context(ctx)
        

        # Print batch metrics            
        if i % print_n == 0 and i > 0:
            sw.add_scalar(tag='Accuracy', value={'batch_size':accuracy.get()[1]}, global_step=i-print_n)
            sw.add_scalar(tag='Speed', value={'batch_size':data.shape[0]*(print_n)/(time.time()-tick)}, global_step=i-print_n)

            print('Batch [{}], Accuracy {:.4f}, Samples/sec: {:.4f}'.format(
                i, accuracy.get()[1], data.shape[0]*(print_n)/(time.time()-tick))
            )
            tick = time.time()
            
        # Forward pass and loss computation
        with autograd.record():
            output = net(data)
            loss = loss_fn(output, label)
            
        # Compute gradient
        loss.backward()
        
        # Update network weights
        trainer.step(data.shape[0])
        
        # Update metric
        if i % print_n_sync == 0:
            accuracy.update(label, output)

        
        if i == 200:
            break
    print('Epoch [{}], Accuracy {:.4f}'.format(e, accuracy.get()[1]))
    print('~Samples/Sec {:.4f}'.format(data.shape[0]*(i+1)/(time.time()-tick_0)))
    accuracy.reset()
# Out:
# Batch [6], Accuracy 0.0000, Samples/sec: 90.3596
# Batch [12], Accuracy 0.0234, Samples/sec: 359.3049
# Batch [18], Accuracy 0.0590, Samples/sec: 342.1272
# Batch [24], Accuracy 0.0716, Samples/sec: 367.2647
# Batch [30], Accuracy 0.0823, Samples/sec: 355.4926
# Batch [36], Accuracy 0.0981, Samples/sec: 357.6430
# Batch [42], Accuracy 0.1138, Samples/sec: 352.5769
# Batch [48], Accuracy 0.1211, Samples/sec: 309.0518
# Batch [54], Accuracy 0.1331, Samples/sec: 368.4355
# Batch [60], Accuracy 0.1417, Samples/sec: 354.0668
# Batch [66], Accuracy 0.1525, Samples/sec: 297.1137
# Batch [72], Accuracy 0.1628, Samples/sec: 380.8876
# Batch [78], Accuracy 0.1723, Samples/sec: 353.5913
# Batch [84], Accuracy 0.1775, Samples/sec: 347.5354
# Batch [90], Accuracy 0.1802, Samples/sec: 356.7312
# Batch [96], Accuracy 0.1846, Samples/sec: 356.4121
# Batch [102], Accuracy 0.1921, Samples/sec: 317.2897
# Batch [108], Accuracy 0.1976, Samples/sec: 360.0092
# Batch [114], Accuracy 0.1998, Samples/sec: 350.9218
# Batch [120], Accuracy 0.2034, Samples/sec: 356.8189
# Batch [126], Accuracy 0.2051, Samples/sec: 348.6792
# Batch [132], Accuracy 0.2093, Samples/sec: 345.2576
# Batch [138], Accuracy 0.2117, Samples/sec: 359.1981
# Batch [144], Accuracy 0.2140, Samples/sec: 355.3284
# Batch [150], Accuracy 0.2158, Samples/sec: 333.7494
# Batch [156], Accuracy 0.2196, Samples/sec: 358.0696
# Batch [162], Accuracy 0.2220, Samples/sec: 333.5548
# Batch [168], Accuracy 0.2234, Samples/sec: 352.5157
# Batch [174], Accuracy 0.2238, Samples/sec: 354.8323
# Batch [180], Accuracy 0.2271, Samples/sec: 355.7251
# Batch [186], Accuracy 0.2285, Samples/sec: 325.5140
# Batch [192], Accuracy 0.2306, Samples/sec: 345.4812
# Batch [198], Accuracy 0.2336, Samples/sec: 355.8050
# Epoch [0], Accuracy 0.2349
# ~Samples/Sec 320.6620
# CPU times: user 38.4 s, sys: 24.1 s, total: 1min 2s
# Wall time: 1min

# %% [markdown]
# | Type              | CPU (%) | GPU Util (%)         | GPU Memory (GB) | GPU Memory I/O (%) | Samples / sec         |
# |---------          |---------|--------------        |-----------------|--------------------|----------------       |
# | 1) Naive          | 10%     |    [0-80]%           |     70%         |     [0-53]%        |  141                  |
# | 2) Multiprocessing| [30-45]%|    [74-93]%          |     70%         |     [50-60]%       |  302                  |
# | 3) Hybridization  | [30-45]%|    [83-94]%          |     70%         |     [50-60]%       |  320                  |
# | 4) Synchronization| [30-45]%|    [90-96]%          |     75%         |     [50-60]%       |  322                  |
# | 5) Hyperparameters| [30-35]%|    [90-98]%          |     86%         |     [55-65]%       |  335                  |

# %% [markdown]
# ## 6) Float16

# %%
net.cast('float16')

# %%
trainer = mx.gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate':0.001*1.5, 'momentum':0.9, 'wd':0.00001, 'multi_precision':True})
accuracy.reset()

# %%
# %%time

epoch = 1
print_n_sync = 3
print_n = 6
tick_0 = time.time()

for e in range(epoch):
    tick = time.time()
    for i, (data, label) in enumerate(dataloader_train):
        data = data.as_in_context(ctx).astype('float16')
        label = label.as_in_context(ctx).astype('float16')
        

        # Print batch metrics            
        if i % print_n == 0 and i > 0:
            sw.add_scalar(tag='Accuracy', value={'float_16':accuracy.get()[1]}, global_step=i-print_n)
            sw.add_scalar(tag='Speed', value={'float_16':data.shape[0]*(print_n)/(time.time()-tick)}, global_step=i-print_n)

            print('Batch [{}], Accuracy {:.4f}, Samples/sec: {:.4f}'.format(
                i, accuracy.get()[1], data.shape[0]*(print_n)/(time.time()-tick))
            )
            tick = time.time()
            
        # Forward pass and loss computation
        with autograd.record():
            output = net(data)
            loss = loss_fn(output, label)
            
        # Compute gradient
        loss.backward()
        
        # Update network weights
        trainer.step(data.shape[0])
        
        # Update metric
        if i % print_n_sync == 0:
            accuracy.update(label, output)

        
        if i == 200:
            break
    print('Epoch [{}], Accuracy {:.4f}'.format(e, accuracy.get()[1]))
    print('~Samples/Sec {:.4f}'.format(data.shape[0]*(i+1)/(time.time()-tick_0)))
    accuracy.reset()
# Out:
# Batch [6], Accuracy 0.0000, Samples/sec: 107.7993
# Batch [12], Accuracy 0.0417, Samples/sec: 508.4815
# Batch [18], Accuracy 0.0660, Samples/sec: 415.2883
# Batch [24], Accuracy 0.0859, Samples/sec: 585.7609
# Batch [30], Accuracy 0.1031, Samples/sec: 788.4673
# Batch [36], Accuracy 0.1068, Samples/sec: 662.2215
# Batch [42], Accuracy 0.1183, Samples/sec: 648.1210
# Batch [48], Accuracy 0.1283, Samples/sec: 631.0880
# Batch [54], Accuracy 0.1406, Samples/sec: 621.8217
# Batch [60], Accuracy 0.1437, Samples/sec: 634.5398
# Batch [66], Accuracy 0.1510, Samples/sec: 594.4197
# Batch [72], Accuracy 0.1589, Samples/sec: 643.1447
# Batch [78], Accuracy 0.1671, Samples/sec: 566.3795
# Batch [84], Accuracy 0.1741, Samples/sec: 598.3172
# Batch [90], Accuracy 0.1767, Samples/sec: 722.8400
# Batch [96], Accuracy 0.1807, Samples/sec: 583.9686
# Batch [102], Accuracy 0.1878, Samples/sec: 606.2928
# Batch [108], Accuracy 0.1933, Samples/sec: 602.4563
# Batch [114], Accuracy 0.1971, Samples/sec: 700.1487
# Batch [120], Accuracy 0.2026, Samples/sec: 589.5383
# Batch [126], Accuracy 0.2046, Samples/sec: 546.2898
# Batch [132], Accuracy 0.2095, Samples/sec: 580.7778
# Batch [138], Accuracy 0.2117, Samples/sec: 657.0985
# Batch [144], Accuracy 0.2138, Samples/sec: 654.0779
# Batch [150], Accuracy 0.2169, Samples/sec: 581.5623
# Batch [156], Accuracy 0.2198, Samples/sec: 689.3987
# Batch [162], Accuracy 0.2226, Samples/sec: 527.6567
# Batch [168], Accuracy 0.2243, Samples/sec: 668.7467
# Batch [174], Accuracy 0.2254, Samples/sec: 603.3848
# Batch [180], Accuracy 0.2313, Samples/sec: 648.4084
# Batch [186], Accuracy 0.2335, Samples/sec: 543.3961
# Batch [192], Accuracy 0.2360, Samples/sec: 665.6778
# Batch [198], Accuracy 0.2388, Samples/sec: 613.5950
# Epoch [0], Accuracy 0.2394
# ~Samples/Sec 533.8858
# CPU times: user 23.5 s, sys: 13.3 s, total: 36.8 s
# Wall time: 36.1 s

# %% [markdown]
# ### 7) Good datapoint: Testing theoritical maximum speed without I/O

# %%
batches = 10
tick_0 = time.time()
data = mx.nd.ones((BATCH_SIZE,3,224,224), ctx=ctx, dtype='float16')
for i in range(batches):
    with autograd.record():
        out = net(data)
    out.backward()
    trainer.step(data.shape[0])
out.asnumpy()
mx.nd.waitall()
print('Max Sample Speed {:.4f}'.format(batches*BATCH_SIZE/(time.time()-tick_0)))
# Out:
# Max Sample Speed 781.6764

# %%
553/780
# Out:
# 0.708974358974359

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Achieved 5x increased from Naive approach
# - Reached 90% of maximum speed without I/O

# %% [markdown]
# # Env Variables
#
# https://mxnet.incubator.apache.org/faq/env_var.html
